# %%
import pandas as pd 
df = pd.read_csv("nyc_weather.csv")
df
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/28/2016           37        20        51                 29.90
# 1  1/18/2016           25         6        53                 29.83
# 2  1/15/2016           43        31        62                 29.82
# 3  1/14/2016           30        12        47                 29.95
# 4  1/13/2016           26         4        42                 29.94
# 5   1/1/2016           38        23        52                 30.03
# 6   1/2/2016           36        18        46                 30.02
# 7  1/17/2016           36        23        66                 29.78
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0               10           5.0               0           1       NaN
# 1                9          12.0               T           2      Snow
# 2                9           5.0               T           2       NaN
# 3               10           5.0               T           7       NaN
# 4               10          10.0               0           0       NaN
# 5               10           8.0               0           5       NaN
# 6               10           7.0               0           3       NaN
# 7                8           6.0            0.05           6  Fog-Snow
#
#    WindDirDegrees           new_col
# 0             234  value of the col
# 1             293  value of the col
# 2             101  value of the col
# 3             266  value of the col
# 4             284  value of the col
# 5             281  value of the col
# 6             275  value of the col
# 7             345  value of the col

# %%
df = df.sample(frac=0.50)
df
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 7  1/17/2016           36        23        66                 29.78
# 2  1/15/2016           43        31        62                 29.82
# 1  1/18/2016           25         6        53                 29.83
# 6   1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 7                8           6.0            0.05           6  Fog-Snow
# 2                9           5.0               T           2       NaN
# 1                9          12.0               T           2      Snow
# 6               10           7.0               0           3       NaN
#
#    WindDirDegrees           new_col
# 7             345  value of the col
# 2             101  value of the col
# 1             293  value of the col
# 6             275  value of the col

# %%
df["new_col"] = 'value of the col'
df.to_csv("nyc_weather.csv",index = False)
df
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 7  1/17/2016           36        23        66                 29.78
# 2  1/15/2016           43        31        62                 29.82
# 1  1/18/2016           25         6        53                 29.83
# 6   1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 7                8           6.0            0.05           6  Fog-Snow
# 2                9           5.0               T           2       NaN
# 1                9          12.0               T           2      Snow
# 6               10           7.0               0           3       NaN
#
#    WindDirDegrees           new_col
# 7             345  value of the col
# 2             101  value of the col
# 1             293  value of the col
# 6             275  value of the col

# %%
import pandas as pd
dt = pd.read_excel("Test.xlsx")
dt
# Out:
#          day  temp  wind speed  event
# 0 2017-01-01  32.0           6   Rain
# 1 2017-01-04   NaN           9  Sunny
# 2 2017-01-05   NaN           8   Snow
# 3 2017-01-06   NaN           7    NaN

# %%
new_dt =dt.interpolate()
new_dt
# Out:
#          day  temp  wind speed  event
# 0 2017-01-01  32.0           6   Rain
# 1 2017-01-04  32.0           9  Sunny
# 2 2017-01-05  32.0           8   Snow
# 3 2017-01-06  32.0           7    NaN

# %%
ft=pd.read_excel("Test2.xlsx")
ft
# Out:
#          day  temp  wind speed  event
# 0 2017-01-01  32.0        6.00   Rain
# 1 2017-01-04  30.0        9.00  Sunny
# 2 2017-01-05   NaN        8.00   Snow
# 3 2017-01-06   NaN        7.00    NaN
# 4 2017-01-07   NaN        7.25   Rain

# %%
new_ft = ft.interpolate()
new_ft
# Out:
#          day  temp  wind speed  event
# 0 2017-01-01  32.0        6.00   Rain
# 1 2017-01-04  30.0        9.00  Sunny
# 2 2017-01-05  30.0        8.00   Snow
# 3 2017-01-06  30.0        7.00    NaN
# 4 2017-01-07  30.0        7.25   Rain

# %%
datafram = pd.DataFrame({
    'Name': ['Ahmed','Ali','Omar'],
    'Age' : ['23','20','70']
    
})
datafram
# Out:
#     Name Age
# 0  Ahmed  23
# 1    Ali  20
# 2   Omar  70

# %%
datafram.replace ({'Name':{'Ahmed':'ahmed'}})
# Out:
#     Name Age
# 0  ahmed  23
# 1    Ali  20
# 2   Omar  70

# %%
datafram.replace ({'Age':{'70':'17'}})
# Out:
#     Name Age
# 0  Ahmed  23
# 1    Ali  20
# 2   Omar  17

# %%
import pandas as pd
from functools import reduce
x=pd.read_csv("nyc_weather.csv")
y=pd.read_excel("Test.xlsx")
z=pd.read_excel("Test2.xlsx")

#data = [x,y,z]

#df_merged = reduce(lambda left,right: pd. merge(left,right,on=['uk'],how='outer'), data)

df_merged =  pd.concat([x,y,z],axis=1)
df_merged
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/17/2016         36.0      23.0      66.0                 29.78
# 1  1/15/2016         43.0      31.0      62.0                 29.82
# 2  1/18/2016         25.0       6.0      53.0                 29.83
# 3   1/2/2016         36.0      18.0      46.0                 30.02
# 4        NaN          NaN       NaN       NaN                   NaN
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0              8.0           6.0            0.05         6.0  Fog-Snow
# 1              9.0           5.0               T         2.0       NaN
# 2              9.0          12.0               T         2.0      Snow
# 3             10.0           7.0               0         3.0       NaN
# 4              NaN           NaN             NaN         NaN       NaN
#
#    WindDirDegrees           new_col        day  temp  wind speed  event  \
# 0           345.0  value of the col 2017-01-01  32.0         6.0   Rain
# 1           101.0  value of the col 2017-01-04   NaN         9.0  Sunny
# 2           293.0  value of the col 2017-01-05   NaN         8.0   Snow
# 3           275.0  value of the col 2017-01-06   NaN         7.0    NaN
# 4             NaN               NaN        NaT   NaN         NaN    NaN
#
#          day  temp  wind speed  event
# 0 2017-01-01  32.0        6.00   Rain
# 1 2017-01-04  30.0        9.00  Sunny
# 2 2017-01-05   NaN        8.00   Snow
# 3 2017-01-06   NaN        7.00    NaN
# 4 2017-01-07   NaN        7.25   Rain

# %%
import pandas as pd 
df = pd.read_csv("nyc_weather.csv")
df
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/17/2016           36        23        66                 29.78
# 1  1/15/2016           43        31        62                 29.82
# 2  1/18/2016           25         6        53                 29.83
# 3   1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                8           6.0            0.05           6  Fog-Snow
# 1                9           5.0               T           2       NaN
# 2                9          12.0               T           2      Snow
# 3               10           7.0               0           3       NaN
#
#    WindDirDegrees           new_col
# 0             345  value of the col
# 1             101  value of the col
# 2             293  value of the col
# 3             275  value of the col

# %%
import pandas as pd
dt = pd.read_excel("Test.xlsx")
dt
# Out:
#          day  temp  wind speed  event
# 0 2017-01-01  32.0           6   Rain
# 1 2017-01-04   NaN           9  Sunny
# 2 2017-01-05   NaN           8   Snow
# 3 2017-01-06   NaN           7    NaN

# %%
ft=pd.read_excel("Test2.xlsx")
ft
# Out:
#          day  temp  wind speed  event
# 0 2017-01-01  32.0        6.00   Rain
# 1 2017-01-04  30.0        9.00  Sunny
# 2 2017-01-05   NaN        8.00   Snow
# 3 2017-01-06   NaN        7.00    NaN
# 4 2017-01-07   NaN        7.25   Rain
